-- %% [markdown]
-- # [SETUR]

-- %%
USE [master]
GO

-- %%
/****** Object:  Database [SETUR]    Script Date: 31.07.2023 21:52:17 ******/
CREATE DATABASE [SETUR]
 CONTAINMENT = NONE
 ON  PRIMARY 
( NAME = N'SETUR', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL15.MSSQLSERVER\MSSQL\DATA\SETUR.mdf' , SIZE = 8192KB , MAXSIZE = UNLIMITED, FILEGROWTH = 65536KB )
 LOG ON 
( NAME = N'SETUR_log', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL15.MSSQLSERVER\MSSQL\DATA\SETUR_log.ldf' , SIZE = 8192KB , MAXSIZE = 2048GB , FILEGROWTH = 65536KB )
 WITH CATALOG_COLLATION = DATABASE_DEFAULT
GO
ALTER DATABASE [SETUR] SET COMPATIBILITY_LEVEL = 150
GO
IF (1 = FULLTEXTSERVICEPROPERTY('IsFullTextInstalled'))
begin
EXEC [SETUR].[dbo].[sp_fulltext_database] @action = 'enable'
end
GO
ALTER DATABASE [SETUR] SET ANSI_NULL_DEFAULT OFF 
GO
ALTER DATABASE [SETUR] SET ANSI_NULLS OFF 
GO
ALTER DATABASE [SETUR] SET ANSI_PADDING OFF 
GO
ALTER DATABASE [SETUR] SET ANSI_WARNINGS OFF 
GO
ALTER DATABASE [SETUR] SET ARITHABORT OFF 
GO
ALTER DATABASE [SETUR] SET AUTO_CLOSE OFF 
GO
ALTER DATABASE [SETUR] SET AUTO_SHRINK OFF 
GO
ALTER DATABASE [SETUR] SET AUTO_UPDATE_STATISTICS ON 
GO
ALTER DATABASE [SETUR] SET CURSOR_CLOSE_ON_COMMIT OFF 
GO
ALTER DATABASE [SETUR] SET CURSOR_DEFAULT  GLOBAL 
GO
ALTER DATABASE [SETUR] SET CONCAT_NULL_YIELDS_NULL OFF 
GO
ALTER DATABASE [SETUR] SET NUMERIC_ROUNDABORT OFF 
GO
ALTER DATABASE [SETUR] SET QUOTED_IDENTIFIER OFF 
GO
ALTER DATABASE [SETUR] SET RECURSIVE_TRIGGERS OFF 
GO
ALTER DATABASE [SETUR] SET  DISABLE_BROKER 
GO
ALTER DATABASE [SETUR] SET AUTO_UPDATE_STATISTICS_ASYNC OFF 
GO
ALTER DATABASE [SETUR] SET DATE_CORRELATION_OPTIMIZATION OFF 
GO
ALTER DATABASE [SETUR] SET TRUSTWORTHY OFF 
GO
ALTER DATABASE [SETUR] SET ALLOW_SNAPSHOT_ISOLATION OFF 
GO
ALTER DATABASE [SETUR] SET PARAMETERIZATION SIMPLE 
GO
ALTER DATABASE [SETUR] SET READ_COMMITTED_SNAPSHOT OFF 
GO
ALTER DATABASE [SETUR] SET HONOR_BROKER_PRIORITY OFF 
GO
ALTER DATABASE [SETUR] SET RECOVERY SIMPLE 
GO
ALTER DATABASE [SETUR] SET  MULTI_USER 
GO
ALTER DATABASE [SETUR] SET PAGE_VERIFY CHECKSUM  
GO
ALTER DATABASE [SETUR] SET DB_CHAINING OFF 
GO
ALTER DATABASE [SETUR] SET FILESTREAM( NON_TRANSACTED_ACCESS = OFF ) 
GO
ALTER DATABASE [SETUR] SET TARGET_RECOVERY_TIME = 60 SECONDS 
GO
ALTER DATABASE [SETUR] SET DELAYED_DURABILITY = DISABLED 
GO
ALTER DATABASE [SETUR] SET ACCELERATED_DATABASE_RECOVERY = OFF  
GO
ALTER DATABASE [SETUR] SET QUERY_STORE = OFF
GO

-- %% [markdown]
-- # [dbo].[otel]

-- %%
USE [SETUR]
GO

-- %%
/****** Object:  Table [dbo].[otel]    Script Date: 31.07.2023 21:52:17 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[otel](
	[ID] [int] IDENTITY(1000,1) NOT NULL,
	[ADI] [nvarchar](50) NULL,
	[ŞEHİR] [nvarchar](50) NULL,
	[YILDIZ] [int] NULL,
	[ADRES] [nvarchar](50) NULL,
	[DaireTipi] [nvarchar](50) NULL,
 CONSTRAINT [PK_OTEL] PRIMARY KEY CLUSTERED 
(
	[ID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[personel]

-- %%
/****** Object:  Table [dbo].[personel]    Script Date: 31.07.2023 21:52:17 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[personel](
	[ID] [int] IDENTITY(1000,1) NOT NULL,
	[ADI] [nvarchar](50) NULL,
	[SOYADI] [nvarchar](50) NULL,
PRIMARY KEY CLUSTERED 
(
	[ID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[REZERVASYON]

-- %%
/****** Object:  Table [dbo].[REZERVASYON]    Script Date: 31.07.2023 21:52:17 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[REZERVASYON](
	[ID] [int] IDENTITY(1000,1) NOT NULL,
	[MüşteriAdı] [nvarchar](50) NOT NULL,
	[MüşteriSoyadı] [nvarchar](50) NOT NULL,
	[OTELID] [int] NOT NULL,
	[BaslangicTarihi] [date] NOT NULL,
	[BitişTarihi] [date] NOT NULL,
	[Ödeme] [money] NOT NULL,
	[PersonelID] [int] NOT NULL,
 CONSTRAINT [PK_REZERVASYON] PRIMARY KEY CLUSTERED 
(
	[ID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [SETUR]

-- %%
USE [master]
GO

-- %%
ALTER DATABASE [SETUR] SET  READ_WRITE 
GO
